# %%
# !pip uninstall -y tensorflow keras tf-keras
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Found existing installation: keras 2.12.0
# Uninstalling keras-2.12.0:
#   Successfully uninstalled keras-2.12.0
# WARNING: Skipping tf-keras as it is not installed.

# %%
# !pip install tensorflow-cpu==2.13.0
# !pip install tf-keras
# Out:
# Collecting tensorflow-cpu==2.13.0
#   Downloading tensorflow_cpu-2.13.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorflow-intel==2.13.0 (from tensorflow-cpu==2.13.0)
#   Downloading tensorflow_intel-2.13.0-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (25.2.10)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (18.1.1)
# Collecting numpy<=1.24.3,>=1.22 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.5.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (1.68.1)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading tensorboard-2.13.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\riyaz\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.40.3)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\riyaz\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\riyaz\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (4.9.1)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\riyaz\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\riyaz\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow-cpu==2.13.0)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading tensorflow_cpu-2.13.0-cp311-cp311-win_amd64.whl (2.0 kB)
# Downloading tensorflow_intel-2.13.0-cp311-cp311-win_amd64.whl (276.6 MB)
#    ---------------------------------------- 0.0/276.6 MB ? eta -:--:--
#    ---------------------------------------- 0.2/276.6 MB 6.1 MB/s eta 0:00:46
#    ---------------------------------------- 0.7/276.6 MB 9.3 MB/s eta 0:00:30
#    ---------------------------------------- 1.1/276.6 MB 8.9 MB/s eta 0:00:31
#    ---------------------------------------- 1.5/276.6 MB 8.7 MB/s eta 0:00:32
#    ---------------------------------------- 1.9/276.6 MB 8.4 MB/s eta 0:00:33
#    ---------------------------------------- 2.3/276.6 MB 8.5 MB/s eta 0:00:33
#    ---------------------------------------- 2.7/276.6 MB 8.5 MB/s eta 0:00:33
#    ---------------------------------------- 3.1/276.6 MB 8.6 MB/s eta 0:00:32
#     --------------------------------------- 3.5/276.6 MB 8.3 MB/s eta 0:00:33
#     --------------------------------------- 3.9/276.6 MB 8.4 MB/s eta 0:00:33
#     --------------------------------------- 4.3/276.6 MB 8.4 MB/s eta 0:00:33
#     --------------------------------------- 4.7/276.6 MB 8.3 MB/s eta 0:00:33
#     --------------------------------------- 5.2/276.6 MB 8.4 MB/s eta 0:00:33
#     --------------------------------------- 5.5/276.6 MB 8.4 MB/s eta 0:00:33
#     --------------------------------------- 5.9/276.6 MB 8.3 MB/s eta 0:00:33
#     --------------------------------------- 6.3/276.6 MB 8.3 MB/s eta 0:00:33
#     --------------------------------------- 6.6/276.6 MB 8.2 MB/s eta 0:00:33
#    - -------------------------------------- 7.0/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 7.3/276.6 MB 8.4 MB/s eta 0:00:33
#    - -------------------------------------- 7.7/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 8.1/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 8.4/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 8.9/276.6 MB 8.2 MB/s eta 0:00:33
#    - -------------------------------------- 9.3/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 9.7/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 10.0/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 10.4/276.6 MB 8.4 MB/s eta 0:00:32
#    - -------------------------------------- 10.8/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 11.2/276.6 MB 8.3 MB/s eta 0:00:33
#    - -------------------------------------- 11.6/276.6 MB 8.3 MB/s eta 0:00:32
#    - -------------------------------------- 12.0/276.6 MB 8.2 MB/s eta 0:00:33
#    - -------------------------------------- 12.3/276.6 MB 8.3 MB/s eta 0:00:32
#    - -------------------------------------- 12.6/276.6 MB 8.2 MB/s eta 0:00:33
#    - -------------------------------------- 13.0/276.6 MB 8.2 MB/s eta 0:00:33
#    - -------------------------------------- 13.4/276.6 MB 8.3 MB/s eta 0:00:32
#    - -------------------------------------- 13.8/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 14.2/276.6 MB 8.2 MB/s eta 0:00:33
#    -- ------------------------------------- 14.6/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 14.9/276.6 MB 8.2 MB/s eta 0:00:32
#    -- ------------------------------------- 15.3/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 15.7/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 16.1/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 16.5/276.6 MB 8.4 MB/s eta 0:00:31
#    -- ------------------------------------- 16.9/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 17.3/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 17.7/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 18.1/276.6 MB 8.3 MB/s eta 0:00:32
#    -- ------------------------------------- 18.5/276.6 MB 8.3 MB/s eta 0:00:32
#    -- -------------------------------------
.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Riyaz\anaconda3\Lib\site-packages\tensorflow\~ite'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Riyaz\anaconda3\Lib\site-packages\tensorflow\~ython'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# faiss-cpu 1.12.0 requires numpy<3.0,>=1.25.0, but you have numpy 1.24.3 which is incompatible.
# openai 1.79.0 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.5.0 which is incompatible.
# selenium 4.25.0 requires typing_extensions~=4.9, but you have typing-extensions 4.5.0 which is incompatible.
# sqlalchemy 2.0.25 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# torch 2.7.0 requires typing-extensions>=4.10.0, but you have typing-extensions 4.5.0 which is incompatible.
# Collecting tf-keras
#   Using cached tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow<2.21,>=2.20 (from tf-keras)
#   Using cached tensorflow-2.20.0-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.4.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (23.1)
# Collecting protobuf>=5.28.0 (from tensorflow<2.21,>=2.20->tf-keras)
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.68.1)
# Collecting tensorboard~=2.20.0 (from tensorflow<2.21,>=2.20->tf-keras)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow<2.21,>=2.20->tf-keras)
#   Using cached keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting numpy>=1.26.0 (from tensorflow<2.21,>=2.20->tf-keras)
#   Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.9 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 539.3 kB/s eta 0:00:00
# Requirement already satisfied: h5py>=3.11.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\riyaz\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.41.2)
# Requirement already satisfied: rich in c:\users\riyaz\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\riyaz\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\riyaz\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.13.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.1)
# Requirement already satisfied: pillow in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (10.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\riyaz\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\riyaz\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\riyaz\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\riyaz\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\riyaz\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Using cached tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.20.0-cp311-cp311-win_amd64.whl (331.8 MB)
# Using cached keras-3.11.3-py3-none-any.whl (1.4 MB)
# Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/13.1 MB 6.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/13.1 MB 9.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/13.1 MB 8.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/13.1 MB 8.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.9/13.1 MB 8.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.2/13.1 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.6/13.1 MB 8.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.1 MB 8.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.3/13.1 MB 8.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/13.1 MB 8.5 MB/s eta 0:00:02
#    ------------ --------------------------- 4.1/13.1 MB 8.4 MB/s eta 0:00:02
#    ------------- -------------------------- 4.5/13.1 MB 8.2 MB/s eta 0:00:02
#    -------------- ------------------------- 4.9/13.1 MB 8.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/13.1 MB 8.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/13.1 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 6.0/13.1 MB 8.4 MB/s eta 0:00:01
#    ------------------- -------------------- 6.4/13.1 MB 8.4 MB/s eta 0:00:01
#    -------------------- ------------------- 6.7/13.1 MB 8.3 MB/s eta 0:00:01
#    --------------------- ------------------ 7.1/13.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.5/13.1 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.8/13.1 MB 8.3 MB/s eta 0:00:01
#    ------------------------ --------------- 8.1/13.1 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/13.1 MB 8.3 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/13.1 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 9.1/13.1 MB 8.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.5/13.1 MB 8.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.9/13.1 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.4/13.1 MB 8.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.1 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/13.1 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.6/13.1 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.1 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.1 MB 8.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.1 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 8.0 MB/s eta 0:00:00
# Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: protobuf, numpy, tensorboard, keras, tensorflow, tf-keras
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
# Successfully installed keras-3.11.3 numpy-2.3.4 protobuf-6.33.0 tensorboard-2.20.0 tensorflow-2.20.0 tf-keras-2.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.3.4 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.4 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.3.4 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.3.4 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.3.4 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.3.4 which is incompatible.
# scipy 1.11.4 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.3.4 which is incompatible.
# streamlit 1.40.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.0 which is incompatible.
# tensorflow-intel 2.13.0 requires keras<2.14,>=2.13.1, but you have keras 3.11.3 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.3.4 which is incompatible.
# tensorflow-intel 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# tensorflow-intel 2.13.0 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.20.0 which is incompatible.

# %%
# !pip install wikipedia sentence-transformers faiss-cpu numpy transformers --upgrade
# Out:
# Requirement already satisfied: wikipedia in c:\users\riyaz\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: sentence-transformers in c:\users\riyaz\anaconda3\lib\site-packages (5.1.2)
# Requirement already satisfied: faiss-cpu in c:\users\riyaz\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: numpy in c:\users\riyaz\anaconda3\lib\site-packages (2.3.4)
# Requirement already satisfied: transformers in c:\users\riyaz\anaconda3\lib\site-packages (4.51.3)
# Collecting transformers
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/44.0 kB ? eta -:--:--
#      -------------------------------------- 44.0/44.0 kB 535.7 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in c:\users\riyaz\anaconda3\lib\site-packages (from wikipedia) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (0.31.4)
# Requirement already satisfied: Pillow in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\riyaz\anaconda3\lib\site-packages (from sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging in c:\users\riyaz\anaconda3\lib\site-packages (from faiss-cpu) (23.1)
# Requirement already satisfied: filelock in c:\users\riyaz\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\riyaz\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\riyaz\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\riyaz\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\riyaz\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riyaz\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.10.5)
# Collecting typing_extensions>=4.5.0 (from sentence-transformers)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\riyaz\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\riyaz\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\riyaz\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: colorama in c:\users\riyaz\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\riyaz\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\riyaz\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\riyaz\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Collecting numpy
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\riyaz\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\riyaz\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 15.0 MB/s eta 0:00:01
#    --- ------------------------------------ 0.9/12.0 MB 11.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.3/12.0 MB 10.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.0 MB 9.5 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.0 MB 9.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.0 MB 9.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/12.0 MB 9.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/12.0 MB 9.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.5/12.0 MB 9.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/12.0 MB 9.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.3/12.0 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/12.0 MB 8.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.9/12.0 MB 8.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.3/12.0 MB 8.7 MB/s eta 0:00:01
#    ------------------ --------------------- 5.7/12.0 MB 8.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/12.0 MB 8.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.5/12.0 MB 8.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.8/12.0 MB 8.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.2/12.0 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.6/12.0 MB 8.5 MB/s eta 0:00:01
#    -------------------------- ------------- 8.0/12.0 MB 8.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.0 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.8/12.0 MB 8.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.1/12.0 MB 8.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.5/12.0 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.9/12.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.3/12.0 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.6/12.0 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.0 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  11.7/12.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 8.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ---------------------------------------- 0.0/564.3 kB ? eta -:--:--
#    --------------------------------------  563.2/564.3 kB 17.3 MB/s eta 0:00:01
#    --------------------------------------- 564.3/564.3 kB 11.8 MB/s eta 0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.7 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 10.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 9.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.7 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 8.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB 2.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.6/15.8 MB 12.0 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/15.8 MB 10.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.4/15.8 MB 9.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.8/15.8 MB 9.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/15.8 MB 9.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/15.8 MB 8.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.8/15.8 MB 8.5 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/15.8 MB 8.7 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/15.8 MB 8.5 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/15.8 MB 8.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.3/15.8 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/15.8 MB 8.6 MB/s eta 0:00:02
#    ------------ --------------------------- 5.1/15.8 MB 8.4 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/15.8 MB 8.4 MB/s eta 0:00:02
#    -------------- ------------------------- 5.9/15.8 MB 8.4 MB/s eta 0:00:02
#    --------------- ------------------------ 6.3/15.8 MB 8.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.7/15.8 MB 8.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/15.8 MB 8.4 MB/s eta 0:00:02
#    ------------------- -------------------- 7.5/15.8 MB 8.4 MB/s eta 0:00:01
#    ------------------- -------------------- 7.9/15.8 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 8.3/15.8 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 8.6/15.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.0/15.8 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/15.8 MB 8.4 MB/s eta 0:00:01
#    ------------------------ --------------- 9.8/15.8 MB 8.4 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/15.8 MB 8.4 MB/s eta 0:00:01
#    -------------------------- ------------- 10.6/15.8 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/15.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.4/15.8 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.7/15.8 MB 8.2 MB/s eta 0:00:01
#    ------------------------------ --------- 12.0/15.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.4/15.8 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.7/15.8 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.8 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.4/15.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.8 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.1/15.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/15.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: typing_extensions, numpy, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.31.4
#     Uninstalling huggingface-hub-0.31.4:
#       Successfully uninstalled huggingface-hub-0.31.4
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed huggingface-hub-0.35.3 numpy-1.26.4 tokenizers-0.22.1 transformers-4.57.1 typing_extensions-4.15.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Riyaz\anaconda3\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# streamlit 1.40.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.0 which is incompatible.
# tensorflow-intel 2.13.0 requires keras<2.14,>=2.13.1, but you have keras 3.11.3 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow-intel 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# tensorflow-intel 2.13.0 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.20.0 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.15.0 which is incompatible.

# %%
import wikipedia
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\Riyaz\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def get_wikipedia_content(topic):
    try:
        page = wikipedia.page(topic)
        return page.content
    except wikipedia.exceptions.PageError:
        return None
    except wikipedia.exceptions.DisambiguationError as e:
        # handle cases where the topic is ambiguous
        print(f"Ambiguous topic. Please be more specific. Options: {e.options}")
        return None

# user input
topic = input("Enter a topic to learn about: ")
document = get_wikipedia_content(topic)

if not document:
    print("Could not retrieve information.")
    exit()
# Out:
# Enter a topic to learn about:  RAG pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-mpnet-base-v2")

def split_text(text, chunk_size=256, chunk_overlap=20):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0
    while start < len(tokens):
        end = min(start + chunk_size, len(tokens))
        chunks.append(tokenizer.convert_tokens_to_string(tokens[start:end]))
        if end == len(tokens):
            break
        start = end - chunk_overlap
    return chunks

chunks = split_text(document)
print(f"Number of chunks: {len(chunks)}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# C:\Users\Riyaz\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Riyaz\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (704 > 512). Running this sequence through the model will result in indexing errors
# Number of chunks: 3

# %%
embedding_model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embeddings = embedding_model.encode(chunks)

dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
query = input("Ask a question about the topic: ")
query_embedding = embedding_model.encode([query])

k = 3
distances, indices = index.search(np.array(query_embedding), k)
retrieved_chunks = [chunks[i] for i in indices[0]]
print("Retrieved chunks:")
for chunk in retrieved_chunks:
    print("- " + chunk)
# Out:
# Ask a question about the topic:  what is RAG?
# Retrieved chunks:
# - ##clinical modernbert. bioclinical modernbert was developed in collaboration with the dana - farber cancer institute in collaboration with researchers at harvard university, mit, mcgill university, albany medical college and microsoft research. the company also released as open source, the ettin suite, the first state - of - the - art paired encoder - decoder models, developed with johns hopkins university. between 2020 and 2025, lighton has trained more than 12 large language models. advanced retrieval technology to support production deployment of these models, lighton developed a suite of open - source tools for multi - vector retrieval that enable real - time, updatable search systems. pylate simplifies multi - vector model training, while fastplaid provides a 554 % performance improvement over stanford plaid, making it suitable for enterprise rag pipelines and recommendation systems. pylate - rs extends this capability to browser - based applications through webassembly compilation. these tools transform multi - vector retrieval from a research concept into production - ready technology for dynamic enterprise search and ai agents. = = references = = = = external links = = official website
# - lighton sa is a french company focused on artificial intelligence ( ai ), that develops generative ai solutions for enterprises. its current product is the paradigm platform, an on - prem / secure enterprise generative ai platform. in november 2024, it became europe ' s first listed genai startup to launched an ipo on euronext growth paris. = = history = = = = = early development ( 2016 – 2021 ) = = = lighton was established in 2016 in paris by french engineers and entrepreneurs igor carron, laurent daudet, florent krzakala and sylvain gigan. the founders, with backgrounds in optics and ai, aimed to develop hardware solutions that could accelerate ai computations using optical processing. the company ' s first product, the optical processing unit ( opu ), was launched in 2018. the approach aims to increase the efficiency of massive parallel processing in tasks that involve large - scale data such has large language model. in 2021, one of lighton opu was integrated in jean zay, one of the french national centre for scientific research supercomputer, making it the first of the top500 world ' s most powerful computer using such hardware. = = = enterprise ai platform ( 2020 – present ) = =
# - most powerful computer using such hardware. = = = enterprise ai platform ( 2020 – present ) = = = parallel to this focus, starting in 2020, lighton trained several llms and released a few as open source on several supercomputers. lighton ' s main product is now an on - prem, secure enterprise generative ai platform called paradigm. in 2024, lighton launched an ipo and became europe ' s first listed genai startup. since the end of 2024, lighton ' s solutions were implemented by various entities such as ile - de - france region, safran, groupama, and the french space agency ( cnes ). the company also partnered with orange business and hewlett packard enterprise to integrate its ai software with their cloud and other offerings. language models lighton, also released monoqwen - vision, the first visual document reranker and in collaboration with answerai, released modernbert, a model that has been downloaded more than 20 million times. in 2025, the lighton engineering team released several state of the art models such as reason - moderncolbert, gte - moderncolbert and bioclinical modernbert. bioclinical modernbert was developed in collaboration with the dana -

# %%
qa_model_name = "deepset/roberta-base-squad2"
qa_tokenizer = AutoTokenizer.from_pretrained(qa_model_name)
qa_model = AutoModelForQuestionAnswering.from_pretrained(qa_model_name)
qa_pipeline = pipeline("question-answering", model=qa_model, tokenizer=qa_tokenizer)

context = " ".join(retrieved_chunks)
answer = qa_pipeline(question=query, context=context)
print(f"Answer: {answer['answer']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# C:\Users\Riyaz\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Riyaz\.cache\huggingface\hub\models--deepset--roberta-base-squad2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# Device set to use cpu
# Answer: artificial intelligence
